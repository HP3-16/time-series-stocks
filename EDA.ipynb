# %% [markdown]
# <a href="https://colab.research.google.com/github/amanjain252002/Stock-Price-Prediction/blob/main/Data_Preprocessing_And_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Data Preprocessing

# %%
RELIANCE = pd.read_csv("D:/time-series-stock-pred/equities/RELIANCE.csv")
TATA_MOTORS = pd.read_csv("D:/time-series-stock-pred/equities/TATAMOTORS.csv")
SBIN = pd.read_csv("D:/time-series-stock-pred/equities/SBIN.csv")
ADANI_PORTS = pd.read_csv("D:/time-series-stock-pred/equities/ADANIPORTS.csv")

# %% [markdown]
# ## RELIANCE

# %%
RELIANCE.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close  \
# 0  1996-01-01  14.638248  14.716795  14.541850  14.691803   9.302443
# 1  1996-01-02  14.656100  14.727506  14.470444  14.577553   9.230103
# 2  1996-01-03  14.816763  15.491551  14.656100  14.688232   9.300183
# 3  1996-01-04  14.548991  14.595404  14.356194  14.552561   9.214279
# 4  1996-01-05  14.495436  14.495436  14.327632  14.452592   9.150980
#
#       Volume
# 0   52060684
# 1   84371654
# 2  104661939
# 3  108450132
# 4   83354233

# %%
RELIANCE.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7079 entries, 0 to 7078
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       7079 non-null   object
#  1   Open       7079 non-null   float64
#  2   High       7079 non-null   float64
#  3   Low        7079 non-null   float64
#  4   Close      7079 non-null   float64
#  5   Adj Close  7079 non-null   float64
#  6   Volume     7079 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 387.3+ KB

# %%
RELIANCE.dropna(inplace = True)

# %%
# Change Dtype of Columns
RELIANCE["Date"] = pd.to_datetime(RELIANCE["Date"])
RELIANCE = RELIANCE.astype({"Open": float, "Volume": float})

# %%
# Sort the Database by Date
RELIANCE = RELIANCE.sort_values(by = 'Date', ignore_index = True)

# %%
# Drop rows having Date < '2015-01-01'
RELIANCE = RELIANCE[RELIANCE["Date"] >= '2015-01-01'].reset_index(drop = True)

# %%
RELIANCE.describe()
# Out:
#                                 Date         Open         High          Low  \
# count                           2265  2265.000000  2265.000000  2265.000000
# mean   2019-08-04 22:34:10.331125760  1366.444963  1380.858930  1351.325896
# min              2015-01-01 00:00:00   373.322052   373.824921   364.110138
# 25%              2017-04-21 00:00:00   609.265625   613.060059   602.088074
# 50%              2019-08-06 00:00:00  1183.146484  1192.838501  1170.665894
# 75%              2021-11-22 00:00:00  2169.649170  2189.262939  2144.358887
# max              2024-03-04 00:00:00  2987.100098  3024.899902  2974.449951
# std                              NaN   764.597840   771.645948   757.137198
#
#              Close    Adj Close        Volume
# count  2265.000000  2265.000000  2.265000e+03
# mean   1365.586520  1348.759118  9.431640e+06
# min     370.647614   349.549438  8.528280e+05
# 25%     607.231201   586.410217  5.461924e+06
# 50%    1183.329346  1161.136230  7.454128e+06
# ...

# %% [markdown]
# ## TATA MOTORS

# %%
TATA_MOTORS.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close  Volume
# 0  1991-01-02  20.959597  21.857864  20.959597  21.857864  15.738638       0
# 1  1991-01-03  20.959597  21.857864  20.959597  21.857864  15.738638       0
# 2  1991-01-04  21.857864  21.857864  21.857864  21.857864  15.738638       0
# 3  1991-01-07  20.360750  21.259020  20.061329  21.109308  15.199647       0
# 4  1991-01-08  21.109308  21.109308  21.109308  21.109308  15.199647       0

# %%
TATA_MOTORS.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8385 entries, 0 to 8384
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       8385 non-null   object
#  1   Open       8385 non-null   float64
#  2   High       8385 non-null   float64
#  3   Low        8385 non-null   float64
#  4   Close      8385 non-null   float64
#  5   Adj Close  8385 non-null   float64
#  6   Volume     8385 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 458.7+ KB

# %%
# Drop NULL rows
TATA_MOTORS.dropna(inplace = True)

# %%
TATA_MOTORS["Date"] = pd.to_datetime(TATA_MOTORS["Date"])
TATA_MOTORS = TATA_MOTORS.astype({"Open": float, "Volume": float})

# %%
TATA_MOTORS = TATA_MOTORS.sort_values(by = 'Date', ignore_index = True)

# %%
# Drop rows having Date < '2015-01-01'
TATA_MOTORS = TATA_MOTORS[TATA_MOTORS["Date"] >= '2015-01-01'].reset_index(drop = True)

# %%
TATA_MOTORS.describe()
# Out:
#                                 Date         Open         High          Low  \
# count                           2265  2265.000000  2265.000000  2265.000000
# mean   2019-08-04 22:34:10.331125760   372.393880   377.328354   366.659452
# min              2015-01-01 00:00:00    66.500000    66.900002    63.500000
# 25%              2017-04-21 00:00:00   242.300003   248.800003   231.699997
# 50%              2019-08-06 00:00:00   397.000000   403.350006   390.500000
# 75%              2021-11-22 00:00:00   469.899994   474.950012   463.549988
# max              2024-03-04 00:00:00   993.250000   995.000000   980.099976
# std                              NaN   165.858494   167.113385   164.335505
#
#              Close    Adj Close        Volume
# count  2265.000000  2265.000000  2.265000e+03
# mean    371.705028   370.667243  2.426588e+07
# min      65.300003    65.097115  9.445510e+05
# 25%     240.199997   239.453690  7.287773e+06
# 50%     396.549988   395.317902  1.253440e+07
# ...

# %% [markdown]
# ## SBIN

# %%
SBIN.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close    Volume
# 0  1996-01-01  18.691147  18.978922  18.540184  18.823240  12.409935  43733533
# 1  1996-01-02  18.894005  18.964767  17.738192  18.224106  12.014927  56167280
# 2  1996-01-03  18.327892  18.568489  17.643839  17.738192  11.694573  68296318
# 3  1996-01-04  17.502312  17.832542  17.223972  17.676863  11.654140  86073880
# 4  1996-01-05  17.738192  17.785366  17.459852  17.577793  11.588825  76613039

# %%
SBIN.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7080 entries, 0 to 7079
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       7080 non-null   object
#  1   Open       7080 non-null   float64
#  2   High       7080 non-null   float64
#  3   Low        7080 non-null   float64
#  4   Close      7080 non-null   float64
#  5   Adj Close  7080 non-null   float64
#  6   Volume     7080 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 387.3+ KB

# %%
SBIN.dropna(inplace = True)

# %%
SBIN["Date"] = pd.to_datetime(SBIN["Date"])
SBIN = SBIN.astype({"Open": float, "High": float, "Low": float, "Close": float, "Adj Close": float, "Volume": float})

# %%
SBIN = SBIN.sort_values(by = 'Date', ignore_index = True)

# %%
SBIN = SBIN[SBIN["Date"] >= '2015-01-01'].reset_index(drop = True)

# %%
SBIN.describe()
# Out:
#                                 Date         Open         High          Low  \
# count                           2265  2265.000000  2265.000000  2265.000000
# mean   2019-08-04 22:34:10.331125760   350.236733   354.409669   345.478477
# min              2015-01-01 00:00:00   151.949997   153.199997   148.250000
# 25%              2017-04-21 00:00:00   256.799988   259.649994   253.399994
# 50%              2019-08-06 00:00:00   294.750000   298.850006   290.700012
# 75%              2021-11-22 00:00:00   461.000000   465.950012   456.350006
# max              2024-03-04 00:00:00   774.400024   777.500000   769.000000
# std                              NaN   135.674830   136.646529   134.749548
#
#              Close    Adj Close        Volume
# count  2265.000000  2265.000000  2.265000e+03
# mean    349.790530   337.677893  2.562377e+07
# min     150.850006   142.108383  2.095795e+06
# 25%     256.000000   242.803558  1.285718e+07
# 50%     294.149994   280.122314  1.810014e+07
# ...

# %% [markdown]
# ## ADANI PORTS

# %%
ADANI_PORTS.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2007-11-27  154.000000  207.000000  154.000000  191.800003  175.274399
# 1  2007-11-28  194.000000  197.800003  174.929993  177.000000  161.749619
# 2  2007-11-29  181.000000  182.800003  168.460007  177.399994  162.115143
# 3  2007-11-30  178.000000  191.399994  178.000000  185.800003  169.791397
# 4  2007-12-03  187.949997  198.860001  184.399994  196.000000  179.112518
#
#      Volume
# 0  27262365
# 1  21958915
# 2  25616715
# 3  23047035
# 4  14578850

# %%
ADANI_PORTS.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4010 entries, 0 to 4009
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       4010 non-null   object
#  1   Open       4010 non-null   float64
#  2   High       4010 non-null   float64
#  3   Low        4010 non-null   float64
#  4   Close      4010 non-null   float64
#  5   Adj Close  4010 non-null   float64
#  6   Volume     4010 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 219.4+ KB

# %%
ADANI_PORTS.dropna(inplace = True)

# %%
# Change Dtype of Columns
ADANI_PORTS["Date"] = pd.to_datetime(ADANI_PORTS["Date"])
ADANI_PORTS = ADANI_PORTS.astype({"Open": float, "Volume": float})

# %%
# Sort the Database by Date
ADANI_PORTS = ADANI_PORTS.sort_values(by = 'Date', ignore_index = True)

# %%
# Drop rows having Date < '2015-01-01'
ADANI_PORTS = ADANI_PORTS[ADANI_PORTS["Date"] >= '2015-01-01'].reset_index(drop = True)

# %%
ADANI_PORTS.describe()
# Out:
#                                 Date         Open         High          Low  \
# count                           2265  2265.000000  2265.000000  2265.000000
# mean   2019-08-04 22:34:10.331125760   490.710089   497.923842   482.332957
# min              2015-01-01 00:00:00   171.600006   180.399994   169.149994
# 25%              2017-04-21 00:00:00   327.799988   332.500000   321.299988
# 50%              2019-08-06 00:00:00   383.000000   387.600006   377.200012
# 75%              2021-11-22 00:00:00   717.000000   727.000000   704.000000
# max              2024-03-04 00:00:00  1345.250000  1356.550049  1336.400024
# std                              NaN   232.593095   235.960079   229.091420
#
#              Close    Adj Close        Volume
# count  2265.000000  2265.000000  2.265000e+03
# mean    489.898145   479.774390  5.725743e+06
# min     171.550003   164.754089  0.000000e+00
# 25%     326.200012   313.929504  2.576054e+06
# 50%     382.149994   369.592743  3.783084e+06
# ...

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %%
Companies = [RELIANCE, TATA_MOTORS, SBIN, ADANI_PORTS]
Companies_Title = ["RELIANCE", "TATA MOTORS", "STATE BANK OF INDIA", "ADANI PORTS"]

# %%
plt.figure(figsize=(18,8))
for index, company in enumerate(Companies):
  plt.subplot(2, 2, index + 1)
  plt.plot(company["Date"], company["Adj Close"])
  plt.title(Companies_Title[index])
  plt.ylabel('Adj Close')

# %% [markdown]
# Reliance has grown slowly reflecting Mukesh Ambani's slow and methodical but efficient approach - acquiring companies and a bouquet of green projects like solar panels, battery and hydrogen. Expansion into 6G and global tie-ups outside RIL.
# We can see from the above graph that TATA MOTORS shares have tremendous growth in the 2022-2024 period. This is due to increasing electric infrastructure and support from the government.
# SBI and Adani Ports have grown together due to mutual money lending saga between the two. Adani's vision and projects are in favor of national portfolio.

# %%
plt.figure(figsize=(18, 8))
for index, company in enumerate(Companies):
  plt.subplot(2, 2, index + 1)
  plt.plot(company["Date"], company["Volume"])
  plt.title(Companies_Title[index])
  plt.ylabel('Volume')

# %% [markdown]
# ### What was the moving average of the various stocks ?

# %%
Moving_Average_Day = [10, 20, 50]
for Moving_Average in Moving_Average_Day:
  for company in Companies:
    column_name = f'Moving Average for {Moving_Average} days'
    company[column_name] = company["Adj Close"].rolling(Moving_Average).mean()

# %%
plt.figure(figsize=(20, 12))
for index, company in enumerate(Companies):
  plt.subplot(2, 2, index + 1)
  plt.plot(company["Date"], company["Adj Close"])
  plt.plot(company["Date"], company["Moving Average for 10 days"])
  plt.plot(company["Date"], company["Moving Average for 20 days"])
  plt.plot(company["Date"], company["Moving Average for 50 days"])
  plt.title(Companies_Title[index])
  plt.legend(("Adj. Close", "Moving Average for 10 days", "Moving Average for 20 days", "Moving Average for 50 days"))

# %% [markdown]
# ### What was the daily return of the stock on average ?

# %% [markdown]
# Now that we've done some baseline analysis, let's go ahead and dive a little deeper. We're now going to analyze the risk of the stock. In order to do so we'll need to take a closer look at the daily changes of the stock, and not just its absolute value.

# %%
for company in Companies:
  company["Daily Return"] = company["Adj Close"].pct_change()

# %%
plt.figure(figsize=(20, 12))
for index, company in enumerate(Companies):
  plt.subplot(2, 2, index + 1)
  plt.plot(company["Date"], company["Daily Return"])
  plt.title(Companies_Title[index])
  plt.ylabel('Daily Return')

# %% [markdown]
# Now, let's get an overall at the average daily return using a histogram.

# %%
plt.figure(figsize=(20, 15))
for index, company in enumerate(Companies):
  plt.subplot(2, 2, index + 1)
  sns.distplot(company["Daily Return"].dropna(), color = "purple")
  plt.title(Companies_Title[index])

# %% [markdown]
# The above graph and the positive kurtosis value indicate that getting extreme daily return values is rare which is often the case of traded equities

# %% [markdown]
# ### What was the correlation between diffrent stocks closing price ?

# %%
Companies_returns = pd.DataFrame()
Companies_returns["RELIANCE"] =RELIANCE["Adj Close"]
Companies_returns["TATA_MOTORS"] =TATA_MOTORS["Adj Close"]
Companies_returns["SBIN"] =SBIN["Adj Close"]
Companies_returns["ADANI_PORTS"] = ADANI_PORTS["Adj Close"]
Companies_returns.head()
# Out:
#      RELIANCE  TATA_MOTORS        SBIN  ADANI_PORTS
# 0  382.812164   491.429077  290.288177   304.542145
# 1  381.798981   504.591034  291.443817   304.351532
# 2  377.616821   516.421997  289.132568   308.592499
# 3  360.478943   494.337524  277.252960   306.734100
# 4  368.325775   486.893890  277.484070   306.019318

# %%
Companies_Daily_returns = Companies_returns.pct_change()
Companies_Daily_returns[1:6]
# Out:
#    RELIANCE  TATA_MOTORS      SBIN  ADANI_PORTS
# 1 -0.002647     0.026783  0.003981    -0.000626
# 2 -0.010954     0.023447 -0.007930     0.013934
# 3 -0.045384    -0.042764 -0.041087    -0.006022
# 4  0.021768    -0.015058  0.000834    -0.002330
# 5 -0.014339     0.036752  0.015659     0.041887

# %% [markdown]
# Now, let's do a correlation plot, to get actual numerical values for the correlation between the stocks closing price

# %%
sns.heatmap(Companies_returns.corr(), annot=True, cmap="YlGnBu")
# Out:
# <Axes: >

# %% [markdown]
# We observe that Reliance, Adani Ports and SBI have mutual correlation

# %%
sns.heatmap(Companies_Daily_returns.corr(), annot=True, cmap="YlGnBu")
# Out:
# <Axes: >

# %% [markdown]
# ### How much value do we put at risk by investing in a paticular stock ?

# %% [markdown]
# There are many ways we can quantify risk, one of the most basic ways using the information we've gathered on daily percentage returns is by comparing the expected return with the standard deviation of the daily returns.

# %%
Returns = Companies_Daily_returns.dropna()
plt.figure(figsize=(20, 5))
plt.scatter(Returns.mean(), Returns.std())
plt.xlabel('Expected return')
plt.ylabel('Risk')

for label, x, y in zip(Companies_Title, Returns.mean(), Returns.std()):
    plt.annotate(label, xy = (x, y), xytext = (10, 0), textcoords = 'offset points')

# %% [markdown]
# We observe Reliance, as always, has followed a slow methodical approach and grown slowly with low risks.
# With the green energy and electric vehicles, TATA can be a high risk high reward product to invest into
# State Bank of India, or any major bank in the banking sector can be the best option for steady and medium growth
# Meanwhile Gautam Adani led Adani Ports has grown considerably due to it's expansion into Ports and Green energy hence ranking it in a skightly higher risk scale`
